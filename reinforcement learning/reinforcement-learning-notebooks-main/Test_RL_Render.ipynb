# %%
## install neccessary dependencies
# !pip install 'gym[box2d]'
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install https://github.com/pyglet/pyglet/archive/pyglet-1.5-maintenance.zip
# !apt-get install ffmpeg -y
# Out:
# Requirement already satisfied: gym[box2d] in /usr/local/lib/python3.7/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.4.1)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.5.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.19.5)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from gym[box2d]) (1.3.0)
# Collecting box2d-py~=2.3.5
#   Downloading box2d_py-2.3.8-cp37-cp37m-manylinux1_x86_64.whl (448 kB)
#      |████████████████████████████████| 448 kB 5.1 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[box2d]) (0.16.0)
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   libgle3
# The following NEW packages will be installed:
#   python-opengl
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 496 kB of archives.
# After this operation, 5,416 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 python-opengl all 3.1.0+dfsg-1 [496 kB]
# Fetched 496 kB in 1s (717 kB/s)
# Selecting previously unselected package python-opengl.
# (Reading database ... 155229 files and directories currently installed.)
# Preparing to unpack .../python-opengl_3.1.0+dfsg-1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-1) ...
# Setting up python-opengl (3.1.0+dfsg-1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xvfb
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 784 kB of archives.
# After this operation, 2,271 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.10 [784 kB]
# Fetched 784 kB in 1s (994 kB/s)
# Selecting previously unselected package xvfb.
# (Reading database ... 157584 files and directories currently installed.)
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.10_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.10) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.10) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-2.2-py3-none-any.whl (15 kB)
# Collecting EasyProcess
#   Downloading EasyProcess-1.1-py3-none-any.whl (8.7 kB)
# Installing collected packages: EasyProcess, pyvirtualdisplay
# Successfully installed EasyProcess-1.1 pyvirtualdisplay-2.2
# Collecting https://github.com/pyglet/pyglet/archive/pyglet-1.5-maintenance.zip
#   Downloading https://github.com/pyglet/pyglet/archive/pyglet-1.5-maintenance.zip
#      - 6.9 MB 3.6 MB/s
# Building wheels for collected packages: pyglet
#   Building wheel for pyglet (setup.py) ... done
#   Created wheel for pyglet: filename=pyglet-1.5.21-py3-none-any.whl size=1129481 sha256=57aaec8f08e4bfacd512b78fdd30ea64d80040cc5aa8030bda32a9e53b5196cd
#   Stored in directory: /root/.cache/pip/wheels/a5/74/e2/595fbf1346ab8312633805be35109e13011091e7e29a01df69
# Successfully built pyglet
# Installing collected packages: pyglet
#   Attempting uninstall: pyglet
#     Found existing installation: pyglet 1.5.0
#     Uninstalling pyglet-1.5.0:
#       Successfully uninstalled pyglet-1.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gym 0.17.3 requires pyglet<=1.5.0,>=1.4.0, but you have pyglet 1.5.21 which is incompatible.
# Successfully installed pyglet-1.5.21
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
## import necessary files

import os
import gym
import numpy as np
from gym import envs
from gym import wrappers
from base64 import b64encode
from ipywidgets import widgets
import matplotlib.pyplot as plt
from IPython.display import HTML
from matplotlib import animation
from IPython.display import display
from pyvirtualdisplay import Display

# setting the display for playing videos and saving them
display = Display(visible=0,size=(600,600))
display.start()

# videos get saved to CWD
monitor_dir = os.getcwd()
env = wrappers.Monitor(env,monitor_dir,video_callable=lambda ep_id: ep_id%1000 == 0,force=True)

# %%
## code for getting video
video = [v for v in os.listdir('./') if 'mp4' in v]
video.sort()

vid_1 = open(video[0],'rb').read()

data_url_1 = "data:video/mp4;base64," + b64encode(vid_1).decode()

## HTML Script
HTML("""
<video width=600 height=600 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url_1)
# Out:
# ---------------------------------------------------------------------------
# GLException                               Traceback (most recent call last)
# <ipython-input-5-811deec61409> in <module>()
#      10
#      11 env = gym.make('CartPole-v1') # insert your favorite environment
# ---> 12 first_frame = env.render(mode='rgb_array')
#
# /usr/local/lib/python3.7/dist-packages/gym/core.py in render(self, mode, **kwargs)
#     238
#     239     def render(self, mode='human', **kwargs):
# --> 240         return self.env.render(mode, **kwargs)
#     241
#     242     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/classic_control/cartpole.py in render(self, mode)
#     172
#     173         if self.viewer is None:
# --> 174             from gym.envs.classic_control import rendering
#     175             self.viewer = rendering.Viewer(screen_width, screen_height)
#     176             l, r, t, b = -cartwidth / 2, cartwidth / 2, cartheight / 2, -cartheight / 2
#
# /usr/local/lib/python3.7/dist-packages/gym/envs/classic_control/rendering.py in <module>()
#      23
#      24 try:
# ---> 25     from pyglet.gl import *
#      26 except ImportError as e:
#      27     raise ImportError('''
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/__init__.py in <module>()
#     230     # trickery is for circular import
#     231     _pyglet.gl = _sys.modules[__name__]
# --> 232     import pyglet.window
#
# /usr/local/lib/python3.7/dist-packages/pyglet/window/__init__.py in <module>()
#    1916 if not _is_pyglet_doc_run:
#    1917     pyglet.window = sys.modules[__name__]
# -> 1918     gl._create_shadow_window()
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/__init__.py in _create_shadow_window()
#     204
#     205     from pyglet.window import Window
# --> 206     _shadow_window = Window(width=1, height=1, visible=False)
#     207     _shadow_window.switch_to()
#     208
#
# /usr/local/lib/python3.7/dist-packages/pyglet/window/xlib/__init__.py in __init__(self, *args, **kwargs)
#     169                     self._event_handlers[message] = func
#     170
# --> 171         super(XlibWindow, self).__init__(*args, **kwargs)
#     172
#     173         global _can_detect_autorepeat
#
# /usr/local/lib/python3.7/dist-packages/pyglet/window/__init__.py in __init__(self, width, height, caption, resizable, style, fullscreen, visible, vsync, file_drops, display, screen, config, context, mode)
#     656         from pyglet import app
#     657         app.windows.add(self)
# --> 658         self._create()
#     659
#     660         # Raise a warning if an OpenGL 2.0 context is not available. This is a common case
#
# /usr/local/lib/python3.7/dist-packages/pyglet/window/xlib/__init__.py in _create(self)
#     283             self.canvas = XlibCanvas(self.display, self._view)
#     284
# --> 285             self.context.attach(self.canvas)
#     286             self.context.set_vsync(self._vsync) # XXX ?
#     287
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/xlib.py in attach(self, canvas)
#     338         self.glx_window = glx.glXCreateWindow(
#     339             self.x_display, self.config._fbconfig, canvas.x_window, None)
# --> 340         self.set_current()
#     341
#     342     def set_current(self):
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/xlib.py in set_current(self)
#     343         glx.glXMakeContextCurrent(
#     344             self.x_display, self.glx_window, self.glx_window, self.glx_context)
# --> 345         super(XlibContext13, self).set_current()
#     346
#     347     def detach(self):
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/base.py in set_current(self)
#     332
#     333         # XXX
# --> 334         gl_info.set_active_context()
#     335         glu_info.set_active_context()
#     336
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/gl_info.py in set_active_context(self)
#      89         self.have_context = True
#      90         if not self._have_info:
# ---> 91             self.vendor = asstr(cast(glGetString(GL_VENDOR), c_char_p).value)
#      92             self.renderer = asstr(cast(glGetString(GL_RENDERER), c_char_p).value)
#      93             self.version = asstr(cast(glGetString(GL_VERSION), c_char_p).value)
#
# /usr/local/lib/python3.7/dist-packages/pyglet/gl/lib.py in errcheck(result, func, arguments)
#     100     context = gl.current_context
#     101     if not context:
# --> 102         raise GLException('No GL context; create a Window first')
#     103     if not context._gl_begin:
#     104         error = gl.glGetError()
#
# GLException: No GL context; create a Window first
